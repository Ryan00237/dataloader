# %%
import sys, numpy, pandas
print(sys.executable)
print(sys.version)
print('numpy', numpy.__version__)
print('pandas', pandas.__version__)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import sys, numpy, pandas
#       2 print(sys.executable)
#       3 print(sys.version)
#
# File ~/anaconda3/envs/quant/lib/python3.13/site-packages/numpy/__init__.py:112
#     109 from . import _distributor_init
#     111 try:
# --> 112     from numpy.__config__ import show_config
#     113 except ImportError as e:
#     114     msg = """Error importing numpy: you should not try to import numpy from
#     115     its source directory; please exit the numpy source tree, and relaunch
#     116     your python interpreter from there."""
#
# File ~/anaconda3/envs/quant/lib/python3.13/site-packages/numpy/__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ...

# %%
import pandas as pd
import mplfinance as mpf

data_path = '/Users/ryan/Documents/repo/dataloader/a_share_minute/sh600000_minute_10_202510300930_202511061500.parquet'
df = pd.read_parquet(data_path)
df.index = pd.to_datetime(df.index)
df = df.loc['2025-10-30':'2025-11-06']
df = df[['open', 'high', 'low', 'close', 'volume']].sort_index()
mpf.plot(df, type='candle', volume=True, style='yahoo', title='SH600000 5分钟K线 (2025-10-30~2025-11-06)')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import mplfinance as mpf
#       4 data_path = '/Users/ryan/Documents/repo/dataloader/a_share_minute/sh600000_minute_10_202510300930_202511061500.parquet'
#
# File ~/anaconda3/envs/quant/lib/python3.13/site-packages/pandas/__init__.py:14
#      12 for _dependency in _hard_dependencies:
#      13     try:
# ---> 14         __import__(_dependency)
#      15     except ImportError as _e:  # pragma: no cover
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File ~/anaconda3/envs/quant/lib/python3.13/site-packages/numpy/__init__.py:112
#     109 from . import _distributor_init
#     111 try:
# --> 112     from numpy.__config__ import show_config
#     113 except ImportError as e:
# ...
